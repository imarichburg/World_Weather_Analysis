# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %% [markdown]
# * Generate a set of 2000 random latitudes and longitudes,
# * Retrieve the nearest city,
# * Perform an API call with the OpenWeatherMap addition to the city weather data  you gathered, and
# * Retrieve current weather description for each city.

# %%
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Import the Pandas module.
import pandas as pd
# Import timeit.
import timeit

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
print(cities)
# Out:
# ['ushuaia', 'kapaa', 'amderma', 'butaritari', 'cayenne', 'rikitea', 'aviles', 'idenao', 'boyolangu', 'college', 'castro', 'mataura', 'provideniya', 'llodio', 'jamestown', 'busselton', 'hermanus', 'hobart', 'ahuimanu', 'zhangye', 'praia da vitoria', 'vostok', 'okha', 'zemio', 'arraial do cabo', 'bredasdorp', 'kismayo', 'dikson', 'mbandaka', 'port alfred', 'punta arenas', 'salalah', 'burnie', 'chifeng', 'mackay', 'luorong', 'albany', 'hithadhoo', 'cooma', 'kirkuk', 'husavik', 'estrela', 'karatau', 'qaanaaq', 'mount isa', 'san patricio', 'fare', 'faanui', 'krasnoarmeyskiy', 'visnes', 'yellowknife', 'nelson bay', 'cidreira', 'saleaula', 'ciudad guayana', 'pangnirtung', 'juegang', 'lompoc', 'tasiilaq', 'new norfolk', 'tiarei', 'taolanaro', 'porto novo', 'thompson', 'cabo san lucas', 'zinapecuaro', 'vanimo', 'phan rang', 'vaini', 'luderitz', 'cabinda', 'saryg-sep', 'lacolle', 'saint-francois', 'puerto ayora', 'yaan', 'belushya guba', 'torbay', 'pizarro', 'ihosy', 'saskylakh', 'evensk', 'porto walter', 'la union', 'ilulissat', 'libreville', 'saint-philippe', 'pangoa', 'oranjemund', 'gat', 'lere', 'clarksdale', 'skalistyy', 'jabiru', 'takoradi', 'sioux lookout', 'nguiu', 'bisauli', 'atuona', 'pascagoula', 'songjianghe', 'bambous virieux', 'portland', 'viedma', 'kamenskoye', 'cape town', 'arkhangelos', 'huarmey', 'danilov', 'henties bay', 'chokurdakh', 'dakar', 'kusk', 'trincomalee', 'georgetown', 'katsuura', 'upernavik', 'safwah', 'kadykchan', 'svetlyy', 'sao filipe', 'teahupoo', 'simbahan', 'eldikan', 'iqaluit', 'vung tau', 'hami', 'grand river south east', 'tabiauea', 'minsk', 'baruun-urt', 'hamilton', 'najran', 'port elizabeth', 'tabuk', 'hilo', 'tak', 'lasa', 'japura', 'sinnamary', 'harper', 'khatanga', 'bereda', 'kavieng', 'ambulu', 'eureka', 'tuktoyaktuk', 'westport', 'lebu', 'igarka', 'bengkulu', 'mehamn', 'broken hill', 'tan an', 'kavaratti', 'araouane', 'illoqqortoormiut', 'barrow', 'richards bay', 'hudiksvall', 'marystown', 'faya', 'vila velha', 'karlovac', 'ostrovnoy', 'east london', 'yulara', 'nome', 'bonthe', 'nipawin', 'guerrero negro', 'trzcianka', 'shache', 'rungata', 'altukhovo', 'dingle', 'camopi', 'tondano', 'carnarvon', 'poum', 'san marcos', 'kyra', 'bluff', 'marrakesh', 'bilma', 'ponta do sol', 'airai', 'kaitangata', 'bullhead city', 'finschhafen', 'mar del plata', 'tabontabon', 'obo', 'lesosibirsk', 'barentsburg', 'clyde river', 'tongling', 'savannakhet', 'monrovia', 'nizhneyansk', 'fort dodge', 'sao felix do xingu', 'norman wells', 'huilong', 'waddan', 'lolua', 'axim', 'acajutla', 'meulaboh', 'bagh', 'bintakay', 'sinsheim', 'ribeira grande', 'atar', 'sapang dalaga', 'vanavara', 'grand gaube', 'klaksvik', 'vila franca do campo', 'palabuhanratu', 'gondar', 'iwaki', 'baoning', 'ayagoz', 'saint anthony', 'asau', 'bodden town', 'paamiut', 'whitehorse', 'san jorge', 'scottsburgh', 'mullaitivu', 'bourail', 'isangel', 'biltine', 'nemuro', 'liverpool', 'mashivka', 'adrar', 'sidi ali', 'lithakia', 'namibe', 'burica', 'chuy', 'grasse', 'tuatapere', 'tiksi', 'carson city', 'katangli', 'sentyabrskiy', 'nikolskoye', 'binghamton', 'puerto escondido', 'kegayli', 'halalo', 'niamey', 'esperance', 'kjollefjord', 'gao', 'narsaq', 'tessalit', 'tomatlan', 'bandarbeyla', 'laguna', 'palembang', 'avarua', 'sao joao da barra', 'svobodnyy', 'mantua', 'tidore', 'safranbolu', 'bolu', 'kampot', 'te anau', 'bratsk', 'jinchengjiang', 'pevek', 'namatanai', 'neiafu', 'yerbogachen', 'ellisras', 'orlik', 'birjand', 'bairiki', 'samatau', 'kieta', 'gimli', 'sumbe', 'soke', 'xichang', 'victoria', 'nabire', 'ekibastuz', 'lagoa', 'kodiak', 'zhetybay', 'ayios kirikos', 'cabra', 'palmer', 'altagracia de orituco', 'teya', 'tura', 'boa vista', 'ancud', 'port-gentil', 'kudat', 'imperia', 'nuuk', 'bathsheba', 'almeirim', 'avera', 'codrington', 'hambantota', 'nantucket', 'ejido', 'simplicio mendes', 'quatre cocos', 'muisne', 'usinsk', 'los llanos de aridane', 'longyearbyen', 'garowe', 'havelock', 'suffolk', 'paragominas', 'grootfontein', 'dunedin', 'tarakan', ...

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list, city_data,  to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters. Initialize counters to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list.
#for i in range(len(cities)):
#    print("I am here")
    # Group cities in sets of 50 for logging purposes.
#    if (i % 50 == 0 and i >= 50):
#        set_count += 1
#        record_count = 1
#        time.sleep(60)

    # Create endpoint URL with each city.
#    city_url = url + "&q=" + cities[i]
#    print("I made it to checkpoint 2")
    # Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | cayenne
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | aviles
# Processing Record 8 of Set 1 | idenao
# Processing Record 9 of Set 1 | boyolangu
# Processing Record 10 of Set 1 | college
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | provideniya
# Processing Record 14 of Set 1 | llodio
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | ahuimanu
# Processing Record 20 of Set 1 | zhangye
# Processing Record 21 of Set 1 | praia da vitoria
# Processing Record 22 of Set 1 | vostok
# Processing Record 23 of Set 1 | okha
# Processing Record 24 of Set 1 | zemio
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | kismayo
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | mbandaka
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | salalah
# Processing Record 33 of Set 1 | burnie
# Processing Record 34 of Set 1 | chifeng
# Processing Record 35 of Set 1 | mackay
# Processing Record 36 of Set 1 | luorong
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | cooma
# Processing Record 40 of Set 1 | kirkuk
# Processing Record 41 of Set 1 | husavik
# Processing Record 42 of Set 1 | estrela
# Processing Record 43 of Set 1 | karatau
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | mount isa
# Processing Record 46 of Set 1 | san patricio
# Processing Record 47 of Set 1 | fare
# Processing Record 48 of Set 1 | faanui
# Processing Record 49 of Set 1 | krasnoarmeyskiy
# Processing Record 50 of Set 1 | visnes
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | nelson bay
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 2 | ciudad guayana
# Processing Record 6 of Set 2 | pangnirtung
# Processing Record 7 of Set 2 | juegang
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | tiarei
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | porto novo
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | zinapecuaro
# Processing Record 17 of Set 2 | vanimo
# Processing Record 18 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | cabinda
# Processing Record 22 of Set 2 | saryg-sep
# Processing Record 23 of Set 2 | lacolle
# Processing Record 24 of Set 2 | saint-francois
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | yaan
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | torbay
# Processing Record 29 of Set 2 | pizarro
# Processing Record 30 of Set 2 | ihosy
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | evensk
# Processing Record 33 of Set 2 | porto walter
# Processing Record 34 of Set 2 | la union
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | libreville
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | pangoa
# Processing Record 39 of Set 2 | oranjemund
# Processing Record 40 of Set 2 | gat
# Processing Record 41 of Set 2 | lere
# Processing Record 42 of Set 2 | clarksdale
# Processing Record 43 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 45 of Set 2 | takoradi
# Processing Record 46 of Set 2 | sioux lookout
# Processing Record 47 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 2 | bisauli
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | pascagoula
# Processing Record 1 of Set 3 | songjianghe
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | portland
# Processing Record 4 of Set 3 | viedma
# Processing Record 5 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | arkhangelos
# City not found. Skipping...
# Processing Record 8 of Set 3 | huarmey
# Processing Record 9 of Set 3 | danilov
# Processing Record 10 of Set 3 | henties bay
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | dakar
# Processing Record 13 of Set 3 | kusk
# City not found. Skipping...
# Processing Record 14 of Set 3 | trincomalee
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | katsuura
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | safwah
# City not found. Skipping...
# Processing Record 19 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 3 | svetlyy
# Processing Record 21 of Set 3 | sao filipe
# Processing Record 22 of Set 3 | teahupoo
# Processing Record 23 of Set 3 | simbahan
# Processing Record 24 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 25 of Set 3 | iqaluit
# Processing Record 26 of Set 3 | vung tau
# Processing Record 27 of Set 3 | hami
# Processing Record 28 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 3 | minsk
# Processing Record 31 of Set 3 | baruun-urt
# Processing Record 32 of Set 3 | hamilton
# Processing Record 33 of Set 3 | najran
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | tabuk
# Processing Record 36 of Set 3 | hilo
# Processing Record 37 of Set 3 | tak
# Processing Record 38 of Set 3 | lasa
# Processing Record 39 of Set 3 | japura
# Processing Record 40 of Set 3 | sinnamary
# Processing Record 41 of Set 3 | harper
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | bereda
# Processing Record 44 of Set 3 | kavieng
# Processing Record 45 of Set 3 | ambulu
# Processing Record 46 of Set 3 | eureka
# Processing Record 47 of Set 3 | tuktoyaktuk
# Processing Record 48 of Set 3 | westport
# Processing Record 49 of Set 3 | lebu
# Processing Record 50 of Set 3 | igarka
# Processing Record 1 of Set 4 | bengkulu
# Processing Record 2 of Set 4 | mehamn
# Processing Record 3 of Set 4 | broken hill
# Processing Record 4 of Set 4 | tan an
# Processing Record 5 of Set 4 | kavaratti
# Processing Record 6 of Set 4 | araouane
# Processing Record 7 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 4 | barrow
# Processing Record 9 of Set 4 | richards bay
# Processing Record 10 of Set 4 | hudiksvall
# Processing Record 11 of Set 4 | marystown
# Processing Record 12 of Set 4 | faya
# Processing Record 13 of Set 4 | vila velha
# Processing Record 14 of Set 4 | karlovac
# Processing Record 15 of Set 4 | ostrovnoy
# Processing Record 16 of Set 4 | east london
# Processing Record 17 of Set 4 | yulara
# Processing Record 18 of Set 4 | nome
# Processing Record 19 of Set 4 | bonthe
# Processing Record 20 of Set 4 | nipawin
# Processing Record 21 of Set 4 | guerrero negro
# Processing Record 22 of Set 4 | trzcianka
# Processing Record 23 of Set 4 | shache
# Processing Record 24 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 4 | altukhovo
# Processing Record 26 of Set 4 | dingle
# Processing Record 27 of Set 4 | camopi
# Processing Record 28 of Set 4 | tondano
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | poum
# Processing Record 31 of Set 4 | san marcos
# Processing Record 32 of Set 4 | kyra
# Processing Record 33 of Set 4 | bluff
# Processing Record 34 of Set 4 | marrakesh
# Processing Record 35 of Set 4 | bilma
# Processing Record 36 of Set 4 | ponta do sol
# Processing Record 37 of Set 4 | airai
# Processing Record 38 of Set 4 | kaitangata
# Processing Record 39 of Set 4 | bullhead city
# Processing Record 40 of Set 4 | finschhafen
# Processing Record 41 of Set 4 | mar del plata
# Processing Record 42 of Set 4 | tabontabon
# Processing Record 43 of Set 4 | obo
# Processing Record 44 of Set 4 | lesosibirsk
# Processing Record 45 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 4 | clyde river
# Processing Record 47 of Set 4 | tongling
# Processing Record 48 of Set 4 | savannakhet
# Processing Record 49 of Set 4 | monrovia
# Processing Record 50 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | fort dodge
# Processing Record 2 of Set 5 | sao felix do xingu
# Processing Record 3 of Set 5 | norman wells
# Processing Record 4 of Set 5 | huilong
# Processing Record 5 of Set 5 | waddan
# Processing Record 6 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 5 | axim
# Processing Record 8 of Set 5 | acajutla
# Processing Record 9 of Set 5 | meulaboh
# Processing Record 10 of Set 5 | bagh
# Processing Record 11 of Set 5 | bintakay
# City not found. Skipping...
# Processing Record 12 of Set 5 | sinsheim
# Processing Record 13 of Set 5 | ribeira grande
# Processing Record 14 of Set 5 | atar
# Processing Record 15 of Set 5 | sapang dalaga
# Processing Record 16 of Set 5 | vanavara
# Processing Record 17 of Set 5 | grand gaube
# Processing Record 18 of Set 5 | klaksvik
# Processing Record 19 of Set 5 | vila franca do campo
# Processing Record 20 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 5 | gondar
# Processing Record 22 of Set 5 | iwaki
# Processing Record 23 of Set 5 | baoning
# Processing Record 24 of Set 5 | ayagoz
# Processing Record 25 of Set 5 | saint anthony
# Processing Record 26 of Set 5 | asau
# Processing Record 27 of Set 5 | bodden town
# Processing Record 28 of Set 5 | paamiut
# Processing Record 29 of Set 5 | whitehorse
# Processing Record 30 of Set 5 | san jorge
# Processing Record 31 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 33 of Set 5 | bourail
# Processing Record 34 of Set 5 | isangel
# Processing Record 35 of Set 5 | biltine
# Processing Record 36 of Set 5 | nemuro
# Processing Record 37 of Set 5 | liverpool
# Processing Record 38 of Set 5 | mashivka
# Processing Record 39 of Set 5 | adrar
# Processing Record 40 of Set 5 | sidi ali
# Processing Record 41 of Set 5 | lithakia
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | burica
# City not found. Skipping...
# Processing Record 44 of Set 5 | chuy
# Processing Record 45 of Set 5 | grasse
# Processing Record 46 of Set 5 | tuatapere
# Processing Record 47 of Set 5 | tiksi
# Processing Record 48 of Set 5 | carson city
# Processing Record 49 of Set 5 | katangli
# Processing Record 50 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 6 | nikolskoye
# Processing Record 2 of Set 6 | binghamton
# Processing Record 3 of Set 6 | puerto escondido
# Processing Record 4 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 5 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 6 | niamey
# Processing Record 7 of Set 6 | esperance
# Processing Record 8 of Set 6 | kjollefjord
# Processing Record 9 of Set 6 | gao
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | tessalit
# Processing Record 12 of Set 6 | tomatlan
# Processing Record 13 of Set 6 | bandarbeyla
# Processing Record 14 of Set 6 | laguna
# Processing Record 15 of Set 6 | palembang
# Processing Record 16 of Set 6 | avarua
# Processing Record 17 of Set 6 | sao joao da barra
# Processing Record 18 of Set 6 | svobodnyy
# Processing Record 19 of Set 6 | mantua
# Processing Record 20 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 21 of Set 6 | safranbolu
# Processing Record 22 of Set 6 | bolu
# Processing Record 23 of Set 6 | kampot
# Processing Record 24 of Set 6 | te anau
# Processing Record 25 of Set 6 | bratsk
# Processing Record 26 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 27 of Set 6 | pevek
# Processing Record 28 of Set 6 | namatanai
# Processing Record 29 of Set 6 | neiafu
# Processing Record 30 of Set 6 | yerbogachen
# Processing Record 31 of Set 6 | ellisras
# Processing Record 32 of Set 6 | orlik
# Processing Record 33 of Set 6 | birjand
# Processing Record 34 of Set 6 | bairiki
# Processing Record 35 of Set 6 | samatau
# City not found. Skipping...
# Processing Record 36 of Set 6 | kieta
# Processing Record 37 of Set 6 | gimli
# Processing Record 38 of Set 6 | sumbe
# Processing Record 39 of Set 6 | soke
# Processing Record 40 of Set 6 | xichang
# Processing Record 41 of Set 6 | victoria
# Processing Record 42 of Set 6 | nabire
# Processing Record 43 of Set 6 | ekibastuz
# Processing Record 44 of Set 6 | lagoa
# Processing Record 45 of Set 6 | kodiak
# Processing Record 46 of Set 6 | zhetybay
# City not found. Skipping...
# Processing Record 47 of Set 6 | ayios kirikos
# City not found. Skipping...
# Processing Record 48 of Set 6 | cabra
# Processing Record 49 of Set 6 | palmer
# Processing Record 50 of Set 6 | altagracia de orituco
# Processing Record 1 of Set 7 | teya
# Processing Record 2 of Set 7 | tura
# Processing Record 3 of Set 7 | boa vista
# Processing Record 4 of Set 7 | ancud
# Processing Record 5 of Set 7 | port-gentil
# Processing Record 6 of Set 7 | kudat
# Processing Record 7 of Set 7 | imperia
# Processing Record 8 of Set 7 | nuuk
# Processing Record 9 of Set 7 | bathsheba
# Processing Record 10 of Set 7 | almeirim
# Processing Record 11 of Set 7 | avera
# Processing Record 12 of Set 7 | codrington
# Processing Record 13 of Set 7 | hambantota
# Processing Record 14 of Set 7 | nantucket
# Processing Record 15 of Set 7 | ejido
# Processing Record 16 of Set 7 | simplicio mendes
# Processing Record 17 of Set 7 | quatre cocos
# Processing Record 18 of Set 7 | muisne
# Processing Record 19 of Set 7 | usinsk
# Processing Record 20 of Set 7 | los llanos de aridane
# Processing Record 21 of Set 7 | longyearbyen
# Processing Record 22 of Set 7 | garowe
# Processing Record 23 of Set 7 | havelock
# Processing Record 24 of Set 7 | suffolk
# Processing Record 25 of Set 7 | paragominas
# Processing Record 26 of Set 7 | grootfontein
# Processing Record 27 of Set 7 | dunedin
# Processing Record 28 of Set 7 | tarakan
# Processing Record 29 of Set 7 | sehithwa
# Processing Record 30 of Set 7 | medea
# Processing Record 31 of Set 7 | hovd
# Processing Record 32 of Set 7 | mahebourg
# Processing Record 33 of Set 7 | salumbar
# Processing Record 34 of Set 7 | ruian
# City not found. Skipping...
# Processing Record 35 of Set 7 | vestmannaeyjar
# Processing Record 36 of Set 7 | fort nelson
# Processing Record 37 of Set 7 | beringovskiy
# Processing Record 38 of Set 7 | knysna
# Processing Record 39 of Set 7 | taybad
# Processing Record 40 of Set 7 | kingsport
# Processing Record 41 of Set 7 | belmonte
# Processing Record 42 of Set 7 | bonavista
# Processing Record 43 of Set 7 | sao francisco do sul
# Processing Record 44 of Set 7 | zeya
# Processing Record 45 of Set 7 | bargi
# Processing Record 46 of Set 7 | tangshan
# Processing Record 47 of Set 7 | nefteyugansk
# Processing Record 48 of Set 7 | mogochin
# City not found. Skipping...
# Processing Record 49 of Set 7 | kollam
# Processing Record 50 of Set 7 | pisco
# Processing Record 1 of Set 8 | bantry
# Processing Record 2 of Set 8 | port hardy
# Processing Record 3 of Set 8 | mende
# Processing Record 4 of Set 8 | bac lieu
# Processing Record 5 of Set 8 | kalmunai
# Processing Record 6 of Set 8 | suzu
# City not found. Skipping...
# Processing Record 7 of Set 8 | sibu
# Processing Record 8 of Set 8 | shaunavon
# Processing Record 9 of Set 8 | manzil salim
# Processing Record 10 of Set 8 | komsomolskiy
# Processing Record 11 of Set 8 | kalomo
# City not found. Skipping...
# Processing Record 12 of Set 8 | cherskiy
# Processing Record 13 of Set 8 | rocha
# Processing Record 14 of Set 8 | souillac
# Processing Record 15 of Set 8 | bonnyville
# Processing Record 16 of Set 8 | constitucion
# Processing Record 17 of Set 8 | padang
# Processing Record 18 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 8 | severo-kurilsk
# Processing Record 20 of Set 8 | srednekolymsk
# Processing Record 21 of Set 8 | touros
# Processing Record 22 of Set 8 | kahului
# Processing Record 23 of Set 8 | labytnangi
# Processing Record 24 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 8 | robertsport
# Processing Record 26 of Set 8 | fonte boa
# Processing Record 27 of Set 8 | tsabong
# Processing Record 28 of Set 8 | nanortalik
# Processing Record 29 of Set 8 | susanville
# Processing Record 30 of Set 8 | charlestown
# Processing Record 31 of Set 8 | taltal
# Processing Record 32 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 8 | coihaique
# Processing Record 34 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 8 | contamana
# Processing Record 36 of Set 8 | reconquista
# Processing Record 37 of Set 8 | deputatskiy
# Processing Record 38 of Set 8 | sao miguel do tapuio
# Processing Record 39 of Set 8 | dauriya
# Processing Record 40 of Set 8 | kirensk
# Processing Record 41 of Set 8 | dalmeny
# Processing Record 42 of Set 8 | beloha
# Processing Record 43 of Set 8 | malumfashi
# Processing Record 44 of Set 8 | keelung
# Processing Record 45 of Set 8 | sukhinichi
# Processing Record 46 of Set 8 | birao
# Processing Record 47 of Set 8 | prainha
# Processing Record 48 of Set 8 | saldanha
# Processing Record 49 of Set 8 | pitkyaranta
# Processing Record 50 of Set 8 | dhandhuka
# Processing Record 1 of Set 9 | mayumba
# Processing Record 2 of Set 9 | anadyr
# Processing Record 3 of Set 9 | luba
# Processing Record 4 of Set 9 | coquimbo
# Processing Record 5 of Set 9 | koslan
# Processing Record 6 of Set 9 | sohag
# Processing Record 7 of Set 9 | raymond
# Processing Record 8 of Set 9 | bella union
# Processing Record 9 of Set 9 | mora
# Processing Record 10 of Set 9 | arlit
# Processing Record 11 of Set 9 | salinopolis
# Processing Record 12 of Set 9 | manta
# Processing Record 13 of Set 9 | honningsvag
# Processing Record 14 of Set 9 | karlskrona
# Processing Record 15 of Set 9 | pecos
# Processing Record 16 of Set 9 | ust-maya
# Processing Record 17 of Set 9 | trairi
# Processing Record 18 of Set 9 | talnakh
# Processing Record 19 of Set 9 | vardo
# Processing Record 20 of Set 9 | kruisfontein
# Processing Record 21 of Set 9 | acarau
# Processing Record 22 of Set 9 | paris
# Processing Record 23 of Set 9 | kondinskoye
# Processing Record 24 of Set 9 | stornoway
# Processing Record 25 of Set 9 | bonga
# Processing Record 26 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 9 | vieira de leiria
# Processing Record 28 of Set 9 | grand forks
# Processing Record 29 of Set 9 | wencheng
# Processing Record 30 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 9 | bubanza
# Processing Record 32 of Set 9 | puerto carreno
# Processing Record 33 of Set 9 | svetlogorsk
# Processing Record 34 of Set 9 | katikati
# Processing Record 35 of Set 9 | pivijay
# Processing Record 36 of Set 9 | abu samrah
# Processing Record 37 of Set 9 | wajima
# Processing Record 38 of Set 9 | harindanga
# Processing Record 39 of Set 9 | rockhampton
# Processing Record 40 of Set 9 | la asuncion
# Processing Record 41 of Set 9 | sitka
# Processing Record 42 of Set 9 | antofagasta
# Processing Record 43 of Set 9 | daokou
# Processing Record 44 of Set 9 | sorland
# Processing Record 45 of Set 9 | saint george
# Processing Record 46 of Set 9 | sand springs
# Processing Record 47 of Set 9 | sambava
# Processing Record 48 of Set 9 | dongsheng
# Processing Record 49 of Set 9 | panaba
# Processing Record 50 of Set 9 | mbour
# Processing Record 1 of Set 10 | yurimaguas
# Processing Record 2 of Set 10 | orcopampa
# Processing Record 3 of Set 10 | alofi
# Processing Record 4 of Set 10 | broome
# Processing Record 5 of Set 10 | saraza
# Processing Record 6 of Set 10 | campbell river
# Processing Record 7 of Set 10 | singkang
# Processing Record 8 of Set 10 | west plains
# Processing Record 9 of Set 10 | hofn
# Processing Record 10 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 10 | presidencia roque saenz pena
# Processing Record 12 of Set 10 | emerald
# Processing Record 13 of Set 10 | gboko
# Processing Record 14 of Set 10 | hasaki
# Processing Record 15 of Set 10 | fortuna
# Processing Record 16 of Set 10 | kautokeino
# Processing Record 17 of Set 10 | ballina
# Processing Record 18 of Set 10 | ferreira do alentejo
# Processing Record 19 of Set 10 | werda
# Processing Record 20 of Set 10 | belgaum
# Processing Record 21 of Set 10 | umm kaddadah
# Processing Record 22 of Set 10 | vreed en hoop
# City not found. Skipping...
# Processing Record 23 of Set 10 | inhambane
# Processing Record 24 of Set 10 | jiangkou
# Processing Record 25 of Set 10 | yakeshi
# Processing Record 26 of Set 10 | soure
# Processing Record 27 of Set 10 | staraya poltavka
# Processing Record 28 of Set 10 | pachmarhi
# Processing Record 29 of Set 10 | hokitika
# Processing Record 30 of Set 10 | kodar
# Processing Record 31 of Set 10 | warrington
# Processing Record 32 of Set 10 | maniitsoq
# Processing Record 33 of Set 10 | leningradskiy
# Processing Record 34 of Set 10 | hohhot
# Processing Record 35 of Set 10 | cockburn town
# Processing Record 36 of Set 10 | san clemente
# Processing Record 37 of Set 10 | rediu
# Processing Record 38 of Set 10 | ust-kulom
# Processing Record 39 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 10 | la ronge
# Processing Record 41 of Set 10 | malatya
# Processing Record 42 of Set 10 | coari
# Processing Record 43 of Set 10 | virginia beach
# Processing Record 44 of Set 10 | shubarkuduk
# Processing Record 45 of Set 10 | kashi
# Processing Record 46 of Set 10 | rio gallegos
# Processing Record 47 of Set 10 | eyl
# Processing Record 48 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 10 | tiznit
# Processing Record 50 of Set 10 | nurota
# Processing Record 1 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 11 | curanilahue
# Processing Record 3 of Set 11 | bethel
# Processing Record 4 of Set 11 | naze
# Processing Record 5 of Set 11 | amahai
# Processing Record 6 of Set 11 | neuquen
# Processing Record 7 of Set 11 | agropoli
# Processing Record 8 of Set 11 | flinders
# Processing Record 9 of Set 11 | oriximina
# Processing Record 10 of Set 11 | rio grande
# Processing Record 11 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 11 | vao
# Processing Record 13 of Set 11 | lodja
# Processing Record 14 of Set 11 | warri
# Processing Record 15 of Set 11 | jalu
# Processing Record 16 of Set 11 | gizo
# Processing Record 17 of Set 11 | barra do garcas
# Processing Record 18 of Set 11 | korla
# Processing Record 19 of Set 11 | juneau
# Processing Record 20 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 11 | comodoro rivadavia
# Processing Record 22 of Set 11 | aljezur
# Processing Record 23 of Set 11 | novyy yarychiv
# Processing Record 24 of Set 11 | baykit
# Processing Record 25 of Set 11 | haysyn
# Processing Record 26 of Set 11 | the valley
# Processing Record 27 of Set 11 | lata
# Processing Record 28 of Set 11 | nizwa
# Processing Record 29 of Set 11 | olinda
# Processing Record 30 of Set 11 | kulhudhuffushi
# Processing Record 31 of Set 11 | tual
# Processing Record 32 of Set 11 | tautira
# Processing Record 33 of Set 11 | saratoga springs
# Processing Record 34 of Set 11 | banyuwangi
# Processing Record 35 of Set 11 | amuntai
# Processing Record 36 of Set 11 | san jeronimo
# Processing Record 37 of Set 11 | piacabucu
# Processing Record 38 of Set 11 | fairbanks
# Processing Record 39 of Set 11 | gouyave
# Processing Record 40 of Set 11 | achinsk
# Processing Record 41 of Set 11 | chernyshevskiy
# Processing Record 42 of Set 11 | jinchang
# Processing Record 43 of Set 11 | tevriz
# Processing Record 44 of Set 11 | bosobolo
# Processing Record 45 of Set 11 | gafanha da nazare
# Processing Record 46 of Set 11 | qaqortoq
# Processing Record 47 of Set 11 | ashland
# Processing Record 48 of Set 11 | geraldton
# Processing Record 49 of Set 11 | kologriv
# Processing Record 50 of Set 11 | taywarah
# Processing Record 1 of Set 12 | jagtial
# Processing Record 2 of Set 12 | algiers
# Processing Record 3 of Set 12 | sur
# Processing Record 4 of Set 12 | ponta delgada
# Processing Record 5 of Set 12 | evanston
# Processing Record 6 of Set 12 | lafia
# Processing Record 7 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 8 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 10 of Set 12 | pathein
# Processing Record 11 of Set 12 | lolodorf
# Processing Record 12 of Set 12 | juigalpa
# Processing Record 13 of Set 12 | paraiso
# Processing Record 14 of Set 12 | lorengau
# Processing Record 15 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 12 | raduzhnyy
# Processing Record 17 of Set 12 | saint-pierre
# Processing Record 18 of Set 12 | berlevag
# Processing Record 19 of Set 12 | atasu
# Processing Record 20 of Set 12 | iralaya
# Processing Record 21 of Set 12 | san cristobal
# Processing Record 22 of Set 12 | kilindoni
# Processing Record 23 of Set 12 | itarema
# Processing Record 24 of Set 12 | methoni
# Processing Record 25 of Set 12 | cocoa beach
# Processing Record 26 of Set 12 | saint-augustin
# Processing Record 27 of Set 12 | mao
# Processing Record 28 of Set 12 | grindavik
# Processing Record 29 of Set 12 | san miguel de cauri
# Processing Record 30 of Set 12 | wadi maliz
# Processing Record 31 of Set 12 | boden
# Processing Record 32 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 33 of Set 12 | marienburg
# Processing Record 34 of Set 12 | hirara
# Processing Record 35 of Set 12 | saint-joseph
# Processing Record 36 of Set 12 | hay river
# Processing Record 37 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 38 of Set 12 | hammerfest
# Processing Record 39 of Set 12 | san carlos
# Processing Record 40 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 41 of Set 12 | krasnoselkup
# Processing Record 42 of Set 12 | maldonado
# Processing Record 43 of Set 12 | agapovka
# Processing Record 44 of Set 12 | teguise
# Processing Record 45 of Set 12 | pacific grove
# Processing Record 46 of Set 12 | plettenberg bay
# Processing Record 47 of Set 12 | povenets
# Processing Record 48 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 12 | necochea
# Processing Record 50 of Set 12 | bennettsville
# Processing Record 1 of Set 13 | kimbe
# Processing Record 2 of Set 13 | innisfail
# Processing Record 3 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 13 | villa union
# Processing Record 5 of Set 13 | ayia marina
# Processing Record 6 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 13 | pemangkat
# Processing Record 8 of Set 13 | osoyoos
# Processing Record 9 of Set 13 | shanghai
# Processing Record 10 of Set 13 | ahome
# Processing Record 11 of Set 13 | sola
# Processing Record 12 of Set 13 | baherden
# Processing Record 13 of Set 13 | gigmoto
# Processing Record 14 of Set 13 | macusani
# Processing Record 15 of Set 13 | tungor
# Processing Record 16 of Set 13 | port macquarie
# Processing Record 17 of Set 13 | lavrentiya
# Processing Record 18 of Set 13 | salinas
# Processing Record 19 of Set 13 | kandrian
# Processing Record 20 of Set 13 | cartagena
# Processing Record 21 of Set 13 | wangdiphodrang
# City not found. Skipping...
# Processing Record 22 of Set 13 | rawson
# Processing Record 23 of Set 13 | targusor
# Processing Record 24 of Set 13 | tatawin
# Processing Record 25 of Set 13 | goderich
# Processing Record 26 of Set 13 | terrace
# Processing Record 27 of Set 13 | berbera
# Processing Record 28 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 29 of Set 13 | katherine
# Processing Record 30 of Set 13 | brigantine
# Processing Record 31 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 13 | santa cruz
# Processing Record 33 of Set 13 | simpang
# Processing Record 34 of Set 13 | vaitape
# Processing Record 35 of Set 13 | marawi
# Processing Record 36 of Set 13 | okandja
# City not found. Skipping...
# Processing Record 37 of Set 13 | ridgecrest
# Processing Record 38 of Set 13 | calama
# Processing Record 39 of Set 13 | suleja
# Processing Record 40 of Set 13 | belawan
# Processing Record 41 of Set 13 | lodwar
# Processing Record 42 of Set 13 | santa rosa
# Processing Record 43 of Set 13 | okhotsk
# Processing Record 44 of Set 13 | turayf
# Processing Record 45 of Set 13 | shubarshi
# Processing Record 46 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 47 of Set 13 | karratha
# Processing Record 48 of Set 13 | gisors
# Processing Record 49 of Set 13 | wuchi
# Processing Record 50 of Set 13 | charkhari
# Processing Record 1 of Set 14 | alice springs
# Processing Record 2 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 3 of Set 14 | vila
# Processing Record 4 of Set 14 | berdorf
# Processing Record 5 of Set 14 | clavier
# Processing Record 6 of Set 14 | esil
# Processing Record 7 of Set 14 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 8 of Set 14 | corrales
# Processing Record 9 of Set 14 | humaita
# Processing Record 10 of Set 14 | cotorra
# Processing Record 11 of Set 14 | palmerston
# Processing Record 12 of Set 14 | steamboat springs
# Processing Record 13 of Set 14 | severobaykalsk
# Processing Record 14 of Set 14 | kracheh
# City not found. Skipping...
# Processing Record 15 of Set 14 | matara
# Processing Record 16 of Set 14 | qui nhon
# Processing Record 17 of Set 14 | pirgos
# Processing Record 18 of Set 14 | brae
# Processing Record 19 of Set 14 | casablanca
# Processing Record 20 of Set 14 | barao de melgaco
# Processing Record 21 of Set 14 | ranong
# Processing Record 22 of Set 14 | waingapu
# Processing Record 23 of Set 14 | lanigan
# Processing Record 24 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 14 | coahuayana
# Processing Record 26 of Set 14 | mitu
# Processing Record 27 of Set 14 | nouadhibou
# Processing Record 28 of Set 14 | tapiramuta
# Processing Record 29 of Set 14 | alwar
# Processing Record 30 of Set 14 | saint-leu
# Processing Record 31 of Set 14 | ipixuna
# Processing Record 32 of Set 14 | maneromango
# Processing Record 33 of Set 14 | nichinan
# Processing Record 34 of Set 14 | oudtshoorn
# Processing Record 35 of Set 14 | port said
# Processing Record 36 of Set 14 | zyukayka
# Processing Record 37 of Set 14 | mandalgovi
# Processing Record 38 of Set 14 | dharchula
# Processing Record 39 of Set 14 | moron
# Processing Record 40 of Set 14 | ozinki
# Processing Record 41 of Set 14 | felipe carrillo puerto
# Processing Record 42 of Set 14 | batagay-alyta
# Processing Record 43 of Set 14 | qasigiannguit
# Processing Record 44 of Set 14 | opuwo
# Processing Record 45 of Set 14 | muroto
# Processing Record 46 of Set 14 | douglas
# Processing Record 47 of Set 14 | dera din panah
# City not found. Skipping...
# Processing Record 48 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 14 | victor harbor
# Processing Record 50 of Set 14 | jiujiang
# Processing Record 1 of Set 15 | veseloyarsk
# Processing Record 2 of Set 15 | huancabamba
# Processing Record 3 of Set 15 | vicente guerrero
# Processing Record 4 of Set 15 | vuktyl
# Processing Record 5 of Set 15 | savannah bight
# Processing Record 6 of Set 15 | hobyo
# Processing Record 7 of Set 15 | sistranda
# Processing Record 8 of Set 15 | camapua
# Processing Record 9 of Set 15 | pervomayskiy
# Processing Record 10 of Set 15 | mackenzie
# Processing Record 11 of Set 15 | mahibadhoo
# Processing Record 12 of Set 15 | palana
# Processing Record 13 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 15 | nynashamn
# Processing Record 15 of Set 15 | bermeo
# Processing Record 16 of Set 15 | tilichiki
# Processing Record 17 of Set 15 | bertinoro
# Processing Record 18 of Set 15 | erenhot
# Processing Record 19 of Set 15 | parrita
# Processing Record 20 of Set 15 | penzance
# Processing Record 21 of Set 15 | maneadero
# Processing Record 22 of Set 15 | disna
# Processing Record 23 of Set 15 | swan hill
# Processing Record 24 of Set 15 | awbari
# Processing Record 25 of Set 15 | san policarpo
# City not found. Skipping...
# Processing Record 26 of Set 15 | urumqi
# Processing Record 27 of Set 15 | beira
# Processing Record 28 of Set 15 | villaviciosa
# Processing Record 29 of Set 15 | shimoda
# Processing Record 30 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 15 | mochitlan
# City not found. Skipping...
# Processing Record 32 of Set 15 | mishelevka
# Processing Record 33 of Set 15 | puerto penasco
# Processing Record 34 of Set 15 | swellendam
# Processing Record 35 of Set 15 | otane
# Processing Record 36 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 15 | aksarka
# Processing Record 38 of Set 15 | half moon bay
# Processing Record 39 of Set 15 | posse
# Processing Record 40 of Set 15 | smila
# Processing Record 41 of Set 15 | jian
# Processing Record 42 of Set 15 | benguela
# Processing Record 43 of Set 15 | port hedland
# Processing Record 44 of Set 15 | smithers
# Processing Record 45 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 15 | raga
# Processing Record 47 of Set 15 | meadow lake
# Processing Record 48 of Set 15 | rutland
# Processing Record 49 of Set 15 | mareeba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Ushuaia -54.8000  -68.3000     56.86        67          75       12.66
# 1       Kapaa  22.0752 -159.3190     78.78        73          75        4.00
# 2  Butaritari   3.0707  172.7902     81.59        79          47        9.48
# 3     Cayenne   4.9333  -52.3333     80.10        89          90        4.00
# 4     Rikitea -23.1203 -134.9692     77.52        70          34        7.52
# 5      Aviles  43.5547   -5.9248     54.37        94          60        5.75
# 6      Idenao   4.2475    9.0047     78.24        80         100        0.98
# 7   Boyolangu  -8.1181  111.8935     76.66        90         100        3.18
# 8     College  64.8569 -147.8028      8.26        80          75        5.75
# 9      Castro -24.7911  -50.0119     59.99        87           5       10.49
#
#   Country                 Date
# 0      AR  2021-12-23 23:26:39
# 1      US  2021-12-23 23:29:07
# 2      KI  2021-12-23 23:31:37
# 3      GF  2021-12-23 23:31:37
# 4      PF  2021-12-23 23:31:37
# 5      ES  2021-12-23 23:31:38
# 6      CM  2021-12-23 23:31:38
# 7      ID  2021-12-23 23:31:39
# 8      US  2021-12-23 23:31:39
# 9      BR  2021-12-23 23:31:39

# %%
#Reorder the columns in the city_data_df DataFrame
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0     Ushuaia      AR  2021-12-23 23:26:39 -54.8000  -68.3000     56.86
# 1       Kapaa      US  2021-12-23 23:29:07  22.0752 -159.3190     78.78
# 2  Butaritari      KI  2021-12-23 23:31:37   3.0707  172.7902     81.59
# 3     Cayenne      GF  2021-12-23 23:31:37   4.9333  -52.3333     80.10
# 4     Rikitea      PF  2021-12-23 23:31:37 -23.1203 -134.9692     77.52
#
#    Humidity  Cloudiness  Wind Speed
# 0        67          75       12.66
# 1        73          75        4.00
# 2        79          47        9.48
# 3        89          90        4.00
# 4        70          34        7.52

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
